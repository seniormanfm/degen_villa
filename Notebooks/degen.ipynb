# %% [markdown]
# fetch the top holder of a solana wallet

# %%
import os
from dotenv import load_dotenv
import requests
import pandas as pd
from joblib import dump

# ========================
# LOAD ENV
# ========================
load_dotenv()
MORALIS_API_KEY = os.getenv("MORALIS_API_KEY")
if not MORALIS_API_KEY:
    raise ValueError("MORALIS_API_KEY not set in .env")

# ========================
# CONFIG
# ========================
TOKEN_MINT = input("Enter Solana token mint address: ").strip()
CHAIN = "mainnet"
LIMIT = 25  # top N holders

DB_FOLDER = r"C:\Users\daddy brian\Desktop\projects\degenvilla\database"
os.makedirs(DB_FOLDER, exist_ok=True)
DB_PATH = os.path.join(DB_FOLDER, f"{TOKEN_MINT}_top_holders.pkl")

# ========================
# FETCH TOP HOLDERS
# ========================
url = f"https://solana-gateway.moralis.io/token/{CHAIN}/{TOKEN_MINT}/top-holders"
headers = {"Accept": "application/json", "X-API-Key": MORALIS_API_KEY}
params = {"limit": LIMIT}

response = requests.get(url, headers=headers, params=params)
response.raise_for_status()
data = response.json().get("result", [])
if not data:
    raise ValueError(f"No top holders found for token {TOKEN_MINT}")

# ========================
# PROCESS DATA
# ========================
df = pd.DataFrame(data)

# Optional: percent of total supply
if "balance" in df.columns and "total_supply" in df.columns:
    df["percent_of_supply"] = (df["balance"] / df["total_supply"]) * 100

# ========================
# SAVE DATA
# ========================
dump(df, DB_PATH)
print(f"\n💾 Top {LIMIT} holders saved to {DB_PATH}")
print("\nTop holders preview:")
print(df.head(LIMIT))
# Out:
# 💾 Top 25 holders saved to C:\Users\daddy brian\Desktop\projects\degenvilla\database\WENWENvqqNya429ubCdR81ZmD69brwQaaBYY6p3LCpk_top_holders.pkl
#
# Top holders preview:
#              balance   balanceFormatted  isContract  \
# 0   7242119095859580   72421190958.5958       False
# 1   4905142106040862  49051421060.40862       False
# 2   3185898269292661  31858982692.92661       False
# 3   2274495449984774  22744954499.84774       False
# 4   2156212253577971  21562122535.77971       False
# 5   2142111932938889  21421119329.38889       False
# 6   2000000000000000        20000000000       False
# 7   1455171251766629  14551712517.66629       False
# 8   1159778775703764  11597787757.03764       False
# 9   1091473045744000     10914730457.44       False
# 10   807360087792209   8073600877.92209       False
# 11   760668137155179   7606681371.55179       False
# 12   735369637587480    7353696375.8748       False
# 13   670072556274847   6700725562.74847       False
# 14   636844355638364   6368443556.38364       False
# 15   573836774536450    5738367745.3645       False
# 16   566813620246425   5668136202.46425       False
# 17   558049399248000      5580493992.48       False
# 18   551145791426965   5511457914.26965       False
# 19   524381000030101   5243810000.30101       False
# 20   522839537697868   5228395376.97868       False
# 21   520572336171615   5205723361.71615       False
# 22   500068221329840    5000682213.2984       False
# 23   491363725577579   4913637255.77579       False
# 24   485587533333331   4855875333.33331       False
#
#                                     ownerAddress               usdValue  \
# 0   5LZkATrLwHYCQj2YuVbjjgsDZzBk6YfL4pFQRJmtboT2   594650.3989610301138
# 1    u6PJ8DtQuPFnfmwHbGFULQ4u4EgjDiyYKjVEsynXq2w  402761.21832701517882
# 2   22Wnk8PwyWZV7BfkZGJEKT9jGGdtvu7xY6EXeRh7zkBa  261594.10689162039471
# 3   DLzPkF5UuNKhQgtMFh2cu5U6aYji5YKyqMiBpYCMKy4R  186758.82139824979314
# 4   ASTyfSima4LLAdDgoFGkgqoKowG1LZFDr9fAQrg7iaJZ  177046.58814128719881
# 5   6FEVkH17P9y8Q9aCkDdPcMDjvj7SVxrTETaYEm8f51Jy  175888.81081361217579
# 6   AGVhmrhDi3RKLu9nxnRqp3CUpaG3SVeYXWkWcygHAk8N                 164220
# 7   G7NRHCWifY89PrqaYMgLHZXfDvRMDLAYNbMVX1FhDh7G  119484.11148255790719
# 8   A77HErqtfN1hLLpvZ9pCtu66FEtM8BveoaKbbMoZ4RiR   95229.43527303606204
# 9   EFE3j1pcSP1paUzA86zW7989ZjsFP2J7ginyUqo4ewqR      89620.85178603984
# 10  9D8xSHWqF9NJWqCtn3rNxYEox63aCbWxYzTMfMur7Cc9   66292.33680861828099
# 11  Da6stGVT84XeipdZ9hc7hWWF3fFGvY4hqHNnUqAPgX4n   62458.46074181174769
# 12  BoSSb33swX6VXWrUFPt1cFren1oRQqM1L4gqwNUmz3GC    60381.2009423079828
# 13  BmFdpraQhkiDQE6SnfG5omcA1VwzqfXrwtNYBwWTymy6   55019.65759572768717
# 14  5PAhQiYdLBd6SVdjzBQDxUAEFyDdF5ExNPQfcscnPRj5   52291.29004146606804
# 15  A6u8tWDtSNuEyZSZufoP9TGQvuEREKnpGcNP7xUsYMKq    47117.7375571879095
# 16  4yqgcP2EvCyyE14Zd9H2jPFMK59q67YUz7bBnUcKcfVE   46541.06635843395675
# 17  FZ1t8TZtx7VSCQdBsxvFJiezj9paUBF6Ub7RKA2eTGyE      45821.43617225328
# 18  8TWNcXvh9BXKdgNdRKGAfKzGUYsoVDMKUuAdbMYxCJEA   45254.58093406809615
# 19  Cw32Ny2xcYdpfJmvFd7h2pRhcbcjoJFq8KrrA8YLwZeh   43056.92391247159311
# 20  C57RBagtGDYpTGxwG92gSKQ5ptQr4Wa9qz3yDBB6uu1B   42930.35444037194148
# 21  6LY1JzAFVZsP2a2xKrtU6znQMQ5h4i7tocWdgrkZzkzF   42744.19452305130765
# 22  GRWqbdwRLEyUKJKJfvfYUjxQDcaowTLu3ASBXznB4VKd    41060.6016533931624
# 23  C4679ZqtJhRqQP5fq1GVHdbxmG1eMeUu98kMMYDZGVyQ   40345.87550717501169
# 24  Fam1RXKabKrtWFEzHkQbz1DEkvTnJEKFd9gowfy4WZkw   39871.59236199980841
#
#     percentageRelativeToTotalSupply
# 0                              9.95
# 1                              6.74
# 2                              4.38
# 3                              3.13
# 4                              2.96
# 5                              2.94
# 6                              2.75
# 7                              2.00
# 8                              1.59
# 9                              1.50
# 10                             1.11
# 11                             1.05
# 12                             1.01
# 13                             0.92
# 14                             0.88
# 15                             0.79
# 16                             0.78
# 17                             0.77
# 18                             0.76
# 19                             0.72
# 20                             0.72
# 21                             0.72
# 22                             0.69
# 23                             0.68
# 24                             0.67

# %% [markdown]
# fetch new listed pumpfun token

# %%
import os
import requests
from dotenv import load_dotenv
import json

# Load .env
load_dotenv()
API_KEY = os.getenv("MORALIS_API_KEY")
if not API_KEY:
    raise ValueError("MORALIS_API_KEY not set in .env")

# API endpoint
url = "https://solana-gateway.moralis.io/token/mainnet/exchange/pumpfun/new?limit=10"
headers = {"Accept": "application/json", "X-API-Key": API_KEY}

# Fetch data
response = requests.get(url, headers=headers)
data = response.json()

# Pretty-print JSON (inspect structure)
print("Full response:")
print(json.dumps(data, indent=2))

# Access the list safely
items = data.get("results", [])  # replace "results" with the actual key if different
print("\nNumber of items:", len(items))
if items:
    print("First item:", items[0])
else:
    print("No data")
# Out:
# Full response:
# {
#   "result": [
#     {
#       "tokenAddress": "5jKiFVBwMSxVV31WCXPduDBGXGm1bZcHhfy9fjrvpump",
#       "name": "Rio Films",
#       "symbol": "Rio",
#       "logo": null,
#       "decimals": "6",
#       "priceNative": "0.0000000359117",
#       "priceUsd": "0.000005138",
#       "liquidity": "9729.593373727",
#       "fullyDilutedValuation": "5138",
#       "createdAt": "2026-01-15T16:19:12.000Z"
#     },
#     {
#       "tokenAddress": "4nNmjFyHpKiVu5ba5h9EoJ6t7mcWvTcZcTuY23btiake",
#       "name": "TikTok Coin",
#       "symbol": "TTC",
#       "logo": null,
#       "decimals": "6",
#       "priceNative": "0.0000000287978",
#       "priceUsd": "0.000004120",
#       "liquidity": "8712.463433964",
#       "fullyDilutedValuation": "4120",
#       "createdAt": "2026-01-15T16:19:07.000Z"
#     },
#     {
#       "tokenAddress": "9i94PGXRjhSQ5vq7RvAP2MV5nb7nVaMiutgSuzkxKK7B",
#       "name": "this will go viral",
#       "symbol": "viralcoin",
#       "logo": null,
#       "decimals": "6",
#       "priceNative": "0.0000000279774",
#       "priceUsd": "0.000004003",
#       "liquidity": "8588.128851304",
#       "fullyDilutedValuation": "4003",
#       "createdAt": "2026-01-15T16:19:06.000Z"
#     },
#     {
#       "tokenAddress": "6Dx6BYq8fCkCkes5iqFhh7viNce4dENs8gYJNxR7pump",
#       "name": "Iremotech",
#       "symbol": "Iremotech",
#       "logo": null,
#       "decimals": "6",
#       "priceNative": "0.0000000281154",
#       "priceUsd": "0.000004022",
#       "liquidity": "8608.615707554",
#       "fullyDilutedValuation": "4022",
#       "createdAt": "2026-01-15T16:19:04.000Z"
#     },
#     {
#       "tokenAddress": "ACRqUuW7pQGVaEQzCYCGwXtnN2UMRN7k2nPUqaRnpump",
#       "name": "Absurd Business Services",
#       "symbol": "snakeskin",
#       "logo": null,
#       "decimals": "6",
#       "priceNative": "0.0000000312318",
#       "priceUsd": "0.000004469",
#       "liquidity": "9076.050404608",
#       "fullyDilutedValuation": "4469",
#       "createdAt": "2026-01-15T16:19:03.000Z"
#     },
#     {
#       "tokenAddress": "3xKJgQpyCBwS1YCMhABZJY3SXE9DsNtSuLV6SjPApump",
#       "name": "Not Big Ass",
#       "symbol": "NBA",
#       "logo": null,
#       "decimals": "6",
#       "priceNative": "0.0000000298305",
#       "priceUsd": "0.000004267",
#       "liquidity": "8865.340580624",
#       "fullyDilutedValuation": "4267",
#       "createdAt": "2026-01-15T16:19:03.000Z"
#     },
#     {
#       "tokenAddress": "AsQbbMqBwSuHHDUbCi2rC4Ut6bpqiE1fuvXhHDwPpump",
#       "name": "Jobless Reincarnation",
#       "symbol": "JOB",
#       "logo": null,
#       "decimals": "6",
#       "priceNative": "0.0000000293876",
#       "priceUsd": "0.000004204",
#       "liquidity": "8800.435490176",
#       "fullyDilutedValuation": "4204",
#       "createdAt": "2026-01-15T16:19:00.000Z"
#     },
#     {
#       "tokenAddress": "7xm37iPVozpMyfoXkB1krQq6SKn3YnwJBouUfEJ9pump",
#       "name": "this will go viral",
#       "symbol": "viralcoin",
#       "logo": null,
#       "decimals": "6",
#       "priceNative": "0.0000000312183",
#       "priceUsd": "0.000004466",
#       "liquidity": "9071.920949996",
#       "fullyDilutedValuation": "4466",
#       "createdAt": "2026-01-15T16:19:00.000Z"
#     },
#     {
#       "tokenAddress": "F1TUN47F9K6uEdcoPaVUd1CPgwvo7AGgzts6qJzQQoEc",
#       "name": "ONE TAP = ONE PUMP",
#       "symbol": "FROGTAP",
#       "logo": null,
#       "decimals": "6",
#       "priceNative": "0.0000000284564",
#       "priceUsd": "0.000004070",
#       "liquidity": "8658.762787552",
#       "fullyDilutedValuation": "4070",
#       "createdAt": "2026-01-15T16:18:55.000Z"
#     },
#     {
#       "tokenAddress": "9RhieFVi4EevgYgLgzNufgu25YLew8NRSbbzUnKMpbuY",
#       "name": "Tiktok's Housecoin",
#       "symbol": "Housecoin",
#       "logo": "https://logo.moralis.io/solana-mainnet_9RhieFVi4EevgYgLgzNufgu25YLew8NRSbbzUnKMpbuY_55ed6281f8bf346cd530d71a643090d9.webp",
#       "decimals": "6",
#       "priceNative": "0.0000000293249",
#       "priceUsd": "0.000004197",
#       "liquidity": "8795.681966032",
#       "fullyDilutedValuation": "4197",
#       "createdAt": "2026-01-15T16:18:50.000Z"
#     }
#   ],
#   "pageSize": 10,
#   "page": 1,
#   "cursor": "eyJhbGciOiJIUzI1NiJ9.eyJwYWdlIjoxLCJmcm9tTG9va3VwIjp7InRva2VuQWRkcmVzcyI6IjlSaGllRlZpNEVldmdZZ0xnek51Zmd1MjVZTGV3OE5SU2JielVuS01wYnVZIiwiY2F0ZWdvcnkiOiJwdW1wZnVuOm5ldyIsImNhdGVnb3J5S2V5IjoxNzY4NDkzOTMwfX0.IqV0_jwZfQk5bqfPBwHU5cfIoa1coWINO7oNKDqJEPo"
# }
#
# Number of items: 0
# No data

# %% [markdown]
# solana token analysis

# %%
import os
import requests
from dotenv import load_dotenv
import json

# Load environment variables
load_dotenv()

API_KEY = os.getenv("MORALIS_API_KEY")

if not API_KEY:
    raise ValueError("MORALIS_API_KEY not set in .env")

# Prompt user for contract address
contract_address = input("Enter the token contract address: ").strip()

# API endpoint (dynamically insert contract address)
url = (
    f"https://deep-index.moralis.io/api/v2.2/tokens/{contract_address}/analytics?chain=solana"
)

# Headers
headers = {
    "Accept": "application/json",
    "X-API-Key": API_KEY
}

# Make request
response = requests.get(url, headers=headers)

# Convert to JSON
try:
    data = response.json()
except Exception as e:
    print("Error parsing response:", e)
    data = {}

# Pretty print full response
print(json.dumps(data, indent=2))
# Out:
# {
#   "tokenAddress": "a3W4qutoEJA4232T2gwZUfgYJTetr96pU4SJMwppump",
#   "totalBuyVolume": {
#     "5m": 976.1544579580003,
#     "1h": 44348.058360676,
#     "6h": 523134.2110252649,
#     "24h": 2159246.002146382
#   },
#   "totalSellVolume": {
#     "5m": 1159.643017594,
#     "1h": 81360.67758267699,
#     "6h": 540833.01511643,
#     "24h": 2417042.780457718
#   },
#   "totalBuyers": {
#     "5m": 18,
#     "1h": 125,
#     "6h": 432,
#     "24h": 2495
#   },
#   "totalSellers": {
#     "5m": 22,
#     "1h": 153,
#     "6h": 495,
#     "24h": 1765
#   },
#   "totalBuys": {
#     "5m": 38,
#     "1h": 385,
#     "6h": 2894,
#     "24h": 13146
#   },
#   "totalSells": {
#     "5m": 35,
#     "1h": 529,
#     "6h": 3515,
#     "24h": 14779
#   },
#   "uniqueWallets": {
#     "5m": 32,
#     "1h": 425,
#     "6h": 719,
#     "24h": 3579
#   },
#   "pricePercentChange": {
#     "5m": 0.59311187519765,
#     "1h": -0.59630137675523,
#     "6h": 0.79690092200152,
#     "24h": -4.3287189799157
#   },
#   "usdPrice": "0.097401897",
#   "totalLiquidityUsd": "2392614.8944008057",
#   "totalFullyDilutedValuation": "99496489.6142596"
# }

# %% [markdown]
# top holder

# %%
# Dependencies to install:
# $ python -m pip install requests python-dotenv

import os
import requests
import json
from dotenv import load_dotenv

# Load API key from .env file
load_dotenv()
API_KEY = os.getenv("MORALIS_API_KEY")
if not API_KEY:
    raise ValueError("MORALIS_API_KEY not set in .env")

# Prompt user for contract address
contract_address = input("Enter the token contract address: ").strip()

# Build the URL dynamically
url = f"https://solana-gateway.moralis.io/token/mainnet/{contract_address}/top-holders?limit=25"

headers = {
    "Accept": "application/json",
    "X-API-Key": API_KEY
}

response = requests.get(url, headers=headers)

# Print response in JSON format
try:
    data = response.json()
    print(json.dumps(data, indent=2))
except Exception as e:
    print("Error parsing response as JSON:", e)
    print(response.text)
# Out:
# {
#   "cursor": "eyJhbGciOiJIUzI1NiJ9.eyJsYXN0U2VlbkJhbGFuY2UiOiI1MzAwMDAwMDAwMDAwIiwibGFzdFNlZW5Ib2xkZXIiOiJBV3Z3TEU3TTNvbk5RQ0RxdHJENWRpUjJxcTMxc05RN1BCMUw2UDZGeTE2RSIsInBhZ2UiOjF9.L8-C_tekmyfQ8dhEe1SufrZSnSQpSSk4TelbC42rmdw",
#   "page": 1,
#   "pageSize": 25,
#   "totalSupply": "999657744.568592",
#   "result": [
#     {
#       "balance": "414317803717779",
#       "balanceFormatted": "414317803.717779",
#       "isContract": false,
#       "ownerAddress": "EBxgMjihSYK1UsfsJtNUhYq6RvuzYh5qFzQVfKew79cb",
#       "usdValue": "40355340.042985327226763",
#       "percentageRelativeToTotalSupply": 41.45
#     },
#     {
#       "balance": "45108628351943",
#       "balanceFormatted": "45108628.351943",
#       "isContract": false,
#       "ownerAddress": "6kasXujkm7dJexQ8JeLeZDtUbR2Xh7Htd2CpuPPpVKYS",
#       "usdValue": "4393665.972547231835871",
#       "percentageRelativeToTotalSupply": 4.51
#     },
#     {
#       "balance": "26132500269342",
#       "balanceFormatted": "26132500.269342",
#       "isContract": false,
#       "ownerAddress": "Czg8YpANX4WDFN94di889wYgd9B4EqznJMWFEtDzXYTy",
#       "usdValue": "2545355.099586921741774",
#       "percentageRelativeToTotalSupply": 2.61
#     },
#     {
#       "balance": "22076464635157",
#       "balanceFormatted": "22076464.635157",
#       "isContract": false,
#       "ownerAddress": "AC5RDfQFmDS1deWZos921JfqscXdByf8BKHs5ACWjtW2",
#       "usdValue": "2150289.534517704692829",
#       "percentageRelativeToTotalSupply": 2.21
#     },
#     {
#       "balance": "16925773765292",
#       "balanceFormatted": "16925773.765292",
#       "isContract": false,
#       "ownerAddress": "sdPGX5Zgb2a8o67aHSAezHmcTHe8HRs8HotyHvzhEhT",
#       "usdValue": "1648602.472932273558924",
#       "percentageRelativeToTotalSupply": 1.69
#     },
#     {
#       "balance": "11216880091330",
#       "balanceFormatted": "11216880.09133",
#       "isContract": false,
#       "ownerAddress": "HWf7c3evXY3gghjPxvCmBGhuPaWkE5MVau7EnrJADYck",
#       "usdValue": "1092545.39931707525301",
#       "percentageRelativeToTotalSupply": 1.12
#     },
#     {
#       "balance": "10880513552859",
#       "balanceFormatted": "10880513.552859",
#       "isContract": false,
#       "ownerAddress": "5tf1DYbKDdgwq9NXpeNAgAw2gmj35LCFuzvLctqFfxe3",
#       "usdValue": "1059782.660382676373523",
#       "percentageRelativeToTotalSupply": 1.09
#     },
#     {
#       "balance": "10491920827619",
#       "balanceFormatted": "10491920.827619",
#       "isContract": false,
#       "ownerAddress": "CE4wHeDdSNsXp5hD1o3S1ujLQtn6fqJYFy91Hknp4HPR",
#       "usdValue": "1021932.991783900593243",
#       "percentageRelativeToTotalSupply": 1.05
#     },
#     {
#       "balance": "10188005186273",
#       "balanceFormatted": "10188005.186273",
#       "isContract": false,
#       "ownerAddress": "CkrB848C4xPzPzEGXvs6gnKxtsxV5cprcQS1bw2yZjQ5",
#       "usdValue": "992331.031788828559881",
#       "percentageRelativeToTotalSupply": 1.02
#     },
#     {
#       "balance": "10000026252472",
#       "balanceFormatted": "10000026.252472",
#       "isContract": false,
#       "ownerAddress": "CgL1xNpsAPr6Kwj8wWRS8RYPFsgi1m7BQqdqpx8HozyF",
#       "usdValue": "974021.527040573739384",
#       "percentageRelativeToTotalSupply": 1
#     },
#     {
#       "balance": "9000023111430",
#       "balanceFormatted": "9000023.11143",
#       "isContract": false,
#       "ownerAddress": "CJtQLAQ9bJeX6DvWKK2rGci6Et1BLt7WinVufMsthcGg",
#       "usdValue": "876619.32409712438271",
#       "percentageRelativeToTotalSupply": 0.9
#     },
#     {
#       "balance": "8807656653614",
#       "balanceFormatted": "8807656.653614",
#       "isContract": false,
#       "ownerAddress": "5oNGZWB4y627jHdyfKqQnrBSyeRjGMTVQgJExkKKwcvw",
#       "usdValue": "857882.466186675505758",
#       "percentageRelativeToTotalSupply": 0.88
#     },
#     {
#       "balance": "8788560738269",
#       "balanceFormatted": "8788560.738269",
#       "isContract": false,
#       "ownerAddress": "58vDMEgtJFp1xwptTAX7QfKFpGtYjJ3ZtUbrJR2PDiRC",
#       "usdValue": "856022.487807121096293",
#       "percentageRelativeToTotalSupply": 0.88
#     },
#     {
#       "balance": "8215717038392",
#       "balanceFormatted": "8215717.038392",
#       "isContract": false,
#       "ownerAddress": "8Ldjm2hqbTtcVPYWcLbU5JiU4zjwyBweaCw1S3dgGeKo",
#       "usdValue": "800226.424754602629624",
#       "percentageRelativeToTotalSupply": 0.82
#     },
#     {
#       "balance": "8168158014193",
#       "balanceFormatted": "8168158.014193",
#       "isContract": false,
#       "ownerAddress": "7CHthdgATBBHmeyeAPKaxFVvmZgx71XieVMSAeQEH3Gd",
#       "usdValue": "795594.085578151124121",
#       "percentageRelativeToTotalSupply": 0.82
#     },
#     {
#       "balance": "8000000000002",
#       "balanceFormatted": "8000000.000002",
#       "isContract": false,
#       "ownerAddress": "E3JUgjvTeMazBzTmuWT67ZB99LzGeb8EGgAFfjQHDRtG",
#       "usdValue": "779215.176000194803794",
#       "percentageRelativeToTotalSupply": 0.8
#     },
#     {
#       "balance": "7824401103578",
#       "balanceFormatted": "7824401.103578",
#       "isContract": false,
#       "ownerAddress": "4qxSqMh6iEdbdvtMp8r5MK2psAGKNk57PfGeVo2VhczQ",
#       "usdValue": "762111.510377390687466",
#       "percentageRelativeToTotalSupply": 0.78
#     },
#     {
#       "balance": "7500000000001",
#       "balanceFormatted": "7500000.000001",
#       "isContract": false,
#       "ownerAddress": "7kbpNPsEB4WmB4Gqbia7yLftB9rCXVUeBj5uG1hTZddJ",
#       "usdValue": "730514.227500097401897",
#       "percentageRelativeToTotalSupply": 0.75
#     },
#     {
#       "balance": "7000000000001",
#       "balanceFormatted": "7000000.000001",
#       "isContract": false,
#       "ownerAddress": "9bTqcfpLRCZRdy3K3uwCUQXKYgyfeGjRZJ1aRLZUpGwx",
#       "usdValue": "681813.279000097401897",
#       "percentageRelativeToTotalSupply": 0.7
#     },
#     {
#       "balance": "6630258996673",
#       "balanceFormatted": "6630258.996673",
#       "isContract": false,
#       "ownerAddress": "BCrTEXmWutwPz8qv6w1S5gDbaLnSLpXKM5kSGVWyyfxu",
#       "usdValue": "645799.803877266888681",
#       "percentageRelativeToTotalSupply": 0.66
#     },
#     {
#       "balance": "6565417665408",
#       "balanceFormatted": "6565417.665408",
#       "isContract": false,
#       "ownerAddress": "GSusGbXPnpVXHtphMFqL7j6D2g7BCSni2LmPHqJQTiZv",
#       "usdValue": "639484.135208050478976",
#       "percentageRelativeToTotalSupply": 0.66
#     },
#     {
#       "balance": "6376865918301",
#       "balanceFormatted": "6376865.918301",
#       "isContract": false,
#       "ownerAddress": "5L37KWrxsCZem8tkBLZ23K56LiwWitkcWHMbXEX2ZLda",
#       "usdValue": "621118.837357164416997",
#       "percentageRelativeToTotalSupply": 0.64
#     },
#     {
#       "balance": "5721826988624",
#       "balanceFormatted": "5721826.988624",
#       "isContract": false,
#       "ownerAddress": "GxhQ5LTFc4dTxAXt7aQ4uSKvr8ev9T2QXE9zWKA3pjFP",
#       "usdValue": "557316.802997775019728",
#       "percentageRelativeToTotalSupply": 0.57
#     },
#     {
#       "balance": "5389184906222",
#       "balanceFormatted": "5389184.906222",
#       "isContract": false,
#       "ownerAddress": "FTdcLMrkHdEniwJJqnWbLmpcvRxAcSMx8RBigEJxhzFA",
#       "usdValue": "524916.833149789903134",
#       "percentageRelativeToTotalSupply": 0.54
#     },
#     {
#       "balance": "5300000000000",
#       "balanceFormatted": "5300000",
#       "isContract": false,
#       "ownerAddress": "AWvwLE7M3onNQCDqtrD5diR2qq31sNQ7PB1L6P6Fy16E",
#       "usdValue": "516230.0541",
#       "percentageRelativeToTotalSupply": 0.53
#     }
#   ]
# }

# %% [markdown]
# birdeye new listing

# %%
import requests
import os
from dotenv import load_dotenv
import pandas as pd
from joblib import dump
import time

# Load .env
load_dotenv()
Birdeye_Api_key = os.getenv("Birdeye_Api_key")

url = "https://public-api.birdeye.so/defi/v2/tokens/new_listing"

headers = {
    "accept": "application/json",
    "x-chain": "solana",
    "x-api-key": Birdeye_Api_key
}

all_tokens = []
batch_size = 20
max_records = 100

db_folder = r"C:\Users\daddy brian\Desktop\projects\degenvilla\database"

now = int(time.time())
one_day_ago = now - 86400  # last 24 hours

for offset in range(0, max_records, batch_size):
    params = {
        "limit": batch_size,
        "offset": offset,
        "meme_platform_enabled": 0,
        "sort_by": "created_at",
        "sort_order": "desc",
        "created_at_from": one_day_ago
    }
    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()
    data = response.json()
    tokens = data.get("data", {}).get("items", [])
    if not tokens:
        print(f"⚠️ No items at offset {offset}, stopping early.")
        break
    all_tokens.extend(tokens)

# Convert to pandas DataFrame
df = pd.DataFrame(all_tokens)

print(f"✅ Total tokens fetched: {len(df)}")
print("\nDataFrame Preview:")
print(df.head())

# Save DataFrame to joblib in the specified database folder
save_path = os.path.join(db_folder, "birdeye_new_listings.joblib")
if not df.empty:
    dump(df, save_path)
    print(f"\n💾 DataFrame saved to {save_path}")
else:
    print("\n⚠️ No tokens fetched, nothing saved.")
# Out:
# ✅ Total tokens fetched: 100
#
# DataFrame Preview:
#                                         address   symbol                name  \
# 0  9AyToQMGzPWj8qyXxwQodgzQJiLVL3MLseuTobjqNLMx      FYC        For You Coin
# 1  AAx5MStJyS5z1xWihdysU2Rx9CQDMniwJmZB7CqU13hV     PEPE                PEPE
# 2  GkRRaoVsoy3m2wWWUd34E39H4x9dY2Ww2hGHgpFYtnce  CATFISH             catfish
# 3   S4VoG1RR6hczZhqzsefn7rf9Hm2n5uCenWKKvRdbonk    SHEBA               Sheba
# 4  5p54SpHcUyNVGuEtp7VKU5ZUE8GSpwawPvr9KLFSgear     GEAR  AUDI SPORT QUATTRO
#
#    decimals                         source     liquidityAddedAt  \
# 0         6  meteora_dynamic_bonding_curve  2026-01-15T17:00:04
# 1         6                       pump_amm  2026-01-15T16:59:37
# 2         6  meteora_dynamic_bonding_curve  2026-01-15T16:59:33
# 3         6              raydium_launchlab  2026-01-15T16:59:09
# 4         9  meteora_dynamic_bonding_curve  2026-01-15T16:59:03
#
#                                              logoURI     liquidity
# 0  https://ipfs.io/ipfs/bafkreih5rlf3lxevnappwrff...  25790.924347
# 1  https://cdn.dexscreener.com/cms/images/69468b0...  86156.078932
# 2  https://ipfs.io/ipfs/QmPTLgecEbEGyUPN6ZLc6TmWx...  28408.477745
# 3  https://axiomtrading.sfo3.cdn.digitaloceanspac...   5847.603541
# 4  https://pub-392e3698ab10439a9bf254db45b52c0b.r...   5100.749525
#
# 💾 DataFrame saved to C:\Users\daddy brian\Desktop\projects\degenvilla\database\birdeye_new_listings.joblib

# %% [markdown]
# first set of wallet that interact with a token address

# %%
import os
import requests
from dotenv import load_dotenv

# ========================
# LOAD ENV
# ========================
load_dotenv()
MORALIS_API_KEY = os.getenv("MORALIS_API_KEY")
if not MORALIS_API_KEY:
    raise ValueError("MORALIS_API_KEY not set in .env")

# ========================
# DYNAMIC TOKEN INPUT
# ========================
TOKEN_MINT = input("Enter Solana token mint address: ").strip()
if not TOKEN_MINT:
    raise ValueError("Token mint address cannot be empty")

# ========================
# MORALIS API CALL
# ========================
url = f"https://solana-gateway.moralis.io/token/mainnet/{TOKEN_MINT}/swaps"

headers = {
    "accept": "application/json",
    "X-API-Key": MORALIS_API_KEY
}

params = {
    "limit": 25,
    "order": "ASC",           # earliest interactions first
    "transactionTypes": "buy,sell"
}

response = requests.get(url, headers=headers, params=params)
if response.status_code != 200:
    print("Error:", response.status_code, response.text)
    raise SystemExit

data = response.json()

# ========================
# EXTRACT UNIQUE WALLETS
# ========================
wallets = []
for tx in data.get("result", []):
    wallet = tx.get("walletAddress")
    if wallet and wallet not in wallets:
        wallets.append(wallet)

# ========================
# OUTPUT
# ========================
if wallets:
    print(f"\nFirst wallets that interacted with {TOKEN_MINT}:\n")
    for i, wallet in enumerate(wallets[:20], start=1):
        print(f"{i}. {wallet}")
else:
    print(f"No wallets found for token {TOKEN_MINT}")
# Out:
# First wallets that interacted with WENWENvqqNya429ubCdR81ZmD69brwQaaBYY6p3LCpk:
#
# 1. Dd9Hf78VoEWZ9qt9Szw2EsYBfjJkNcE4Za6gRC2LagK7
# 2. 7LFYBv2FQDY6aw5hL5SBCW2PiHG8TmENxBnfUnCksRbs
# 3. 2bhkQ6uVn32ddiG4Fe3DVbLsrExdb3ubaY6i1G4szEmq
# 4. 9FaT545ui3HodXRu2xa9GBGq6G5vddCBroMsCR6ELHe7
# 5. RxpJfxTPTo4TgZ4GcgXSrEyZfu1mN8sT5HJgGUiBCPN
# 6. 56DFNFWnyRT6oqJq59q3i226Q25YWN7aoUdv6Ujw6Su7
# 7. 62tWnYF3z73Zv6T86Na8fqhaw8Xk7jnfdirBsaaYz7KP
# 8. DCAK36VfExkPdAkYUQg6ewgxyinvcEyPLyHjRbmveKFw
# 9. 6ZfaNoj54ypqfzNWCb2FBiNSwNVzZ3CdBiKvxtmEE28e
# 10. wFPHWHFZTuJkAeh3EfSyrNA6mmMsGWbAMwEcz5F1GcR
# 11. Ee7oGQLorSg8tapxb4ym7Y7vAZUuYHMZEgC6boQQJrcP
# 12. 8ARBpGvHUszvnPWv4p3ZeDLAHMowkn6iaLviMePaNzvT
# 13. 3FLi39QpEuYZL6YEnefLTpaifd4EFXMtQP7M5Vy91qwF

# %% [markdown]
# show earliest buyer, timestamp, amount bought

# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
from joblib import dump

# ========================
# LOAD ENV
# ========================
load_dotenv()
MORALIS_API_KEY = os.getenv("MORALIS_API_KEY")
if not MORALIS_API_KEY:
    raise ValueError("MORALIS_API_KEY not set in .env")

# ========================
# TOKEN INPUT
# ========================
TOKEN_MINT = input("Enter Solana token mint address: ").strip()
if not TOKEN_MINT:
    raise ValueError("Token mint address cannot be empty")

# ========================
# DATABASE PATH
# ========================
DB_PATH = r"C:\Users\daddy brian\Desktop\projects\degenvilla\database"
os.makedirs(DB_PATH, exist_ok=True)

SAVE_FILE = os.path.join(DB_PATH, f"{TOKEN_MINT}_first_20_buyers.pkl")

# ========================
# FETCH TOKEN SWAPS
# ========================
url = f"https://solana-gateway.moralis.io/token/mainnet/{TOKEN_MINT}/swaps"

headers = {
    "accept": "application/json",
    "X-API-Key": MORALIS_API_KEY
}

params = {
    "limit": 50,     # scan enough swaps
    "order": "ASC"    # earliest first
}

response = requests.get(url, headers=headers, params=params)
response.raise_for_status()

results = response.json().get("result", [])
if not results:
    raise ValueError("No swap data found")

# ========================
# EXTRACT FIRST 20 UNIQUE BUYERS
# ========================
seen_wallets = set()
buyers = []

for tx in results:
    if (tx.get("transactionType") or "").lower() != "buy":
        continue

    wallet = tx.get("walletAddress")
    if not wallet or wallet in seen_wallets:
        continue

    buyer = {
        "walletAddress": wallet,
        "blockTimestamp": tx.get("blockTimestamp"),
        "transactionHash": tx.get("transactionHash"),
        "totalValueUsd": tx.get("totalValueUsd"),
    }

    buyers.append(buyer)
    seen_wallets.add(wallet)

    if len(buyers) == 20:
        break

if not buyers:
    raise ValueError("No buy transactions found")

df = pd.DataFrame(buyers)

# ========================
# SAVE RESULT
# ========================
dump(df, SAVE_FILE)

# ========================
# OUTPUT (MATCHING YOUR FORMAT)
# ========================
print("✅ First 20 buyers saved successfully\n")

for i, buyer in enumerate(buyers, start=1):
    print(f"#{i}")
    print("Wallet:", buyer["walletAddress"])
    print("Timestamp:", buyer["blockTimestamp"])
    print("Transaction Hash:", buyer["transactionHash"])
    print("Total Value USD:", buyer["totalValueUsd"])
    print("-" * 50)

print("\n💾 Saved to:", SAVE_FILE)
# Out:
# ✅ First 20 buyers saved successfully
#
# #1
# Wallet: 7tRcXDZMjg2CwrgeJ6q2dwU3h3b6tCHcPWSZFKag3kYz
# Timestamp: 2024-12-17T12:46:04.000Z
# Transaction Hash: 2skfjsbTuia8MF75hiwLbLgvnC2CRBc3A72CDLuTGdnMpT89RNRbyjeMagK9UE4JuuyGLSnLPv766UhjTatbaKAF
# Total Value USD: 10357.236120205242
# --------------------------------------------------
# #2
# Wallet: Fh5qy4YCbzp4dBZwUzcj6iJfmr6ZcGjceERp85K5U9he
# Timestamp: 2024-12-17T12:46:05.000Z
# Transaction Hash: 4JRnZX7ZciJDFa6umaB5F4AWLiV8ijmoSfbS4Xjw2cJTzyrVS2DoRS5gKtqCwFQRPh5uNCzNo8eFJnPKfLE7RrKA
# Total Value USD: 39203.62802562656
# --------------------------------------------------
# #3
# Wallet: 7dGrdJRYtsNR8UYxZ3TnifXGjGc9eRYLq9sELwYpuuUu
# Timestamp: 2024-12-17T12:46:05.000Z
# Transaction Hash: 4YyVBCoTcngie4F6fBGZZsQeUnK1tBtrVYWcVL96MJFCq3C9Z2HaZBZJCEVvQndhJ2bmpyKngdCrfQPCeFPqUmSs
# Total Value USD: 146761.13046356154
# --------------------------------------------------
# #4
# Wallet: 8pY1AukbuPgUE3EetyLa59rFLMimJGT94ZzbMEZcQF4w
# Timestamp: 2024-12-17T12:46:05.000Z
# Transaction Hash: VThhMfPKojJyM8sqt51MncVS1gSiYYW2vnfRVPVBMzZpXAZz7KVquyF1SnszPjF3jRUA6CdEMAa8hk39nG6mo8j
# Total Value USD: 2870.3330107463235
# --------------------------------------------------
# #5
# Wallet: H6FTjrbVduVKWiMDDiyvyXYacK17apFajQwymchXfyDT
# Timestamp: 2024-12-17T12:46:05.000Z
# Transaction Hash: 38HuM9H6z65MjrFcHZRvhvtjHHdYMg13ZFZqiQLocqSgLXnuhUVM3FhsqiAM9fKvuUtCjroxcnDyYFDz6vctRipM
# Total Value USD: 421.15744739798964
# --------------------------------------------------
# #6
# Wallet: EZvyYN1Q98yPJXh8FCTx94ZYFeo6wtJ544hKdAF72QyU
# Timestamp: 2024-12-17T12:46:05.000Z
# Transaction Hash: 31gX9HTcL1DTfnBXTNLuCWHfx1YkgynfxiRcKjMjxSwqy3dUPJkqUzmjhFp3FfqmWxgVUeqSXdgPPBVKepWYZNkA
# Total Value USD: 167069.15295635932
# --------------------------------------------------
# #7
# Wallet: 54EiavhVatcFbcRHKm2swd6eB8reyib3kTkDGScoGjGK
# Timestamp: 2024-12-17T12:46:06.000Z
# Transaction Hash: 4upy1xw6djuQjG2XQy3EcL9Jv7cfP1SdiBJPoPJEnegnLeTrgnnbACugo7zWrEaLr4rWCjoEw1mBTfJM7an3rNuh
# Total Value USD: 90707.48602677336
# --------------------------------------------------
# #8
# Wallet: HmNxnBMda6tqVxTqyphSwADzzLH3KGeYKdnwF1jwr1Q2
# Timestamp: 2024-12-17T12:46:06.000Z
# Transaction Hash: HmjECWyK15tB9PKzTRmiDumt39u7Rub33H4Zz7vjA3CC2UToeAi5WHGr86HjSA9MGRbjxrX6D2t4b9dpSXJL45p
# Total Value USD: 49419.88973558642
# --------------------------------------------------
# #9
# Wallet: EvdyrZbGcHXxDEef7bFCX3aANBMFisWh3MLNJifiqXyA
# Timestamp: 2024-12-17T12:46:06.000Z
# Transaction Hash: 3k2Zp21JSgXvzN9F2ixhqfwSGcAWc7cE5wTe2irB3EpTXgMNc3k13zj1EfsFAszghJdyGujCYaKCoj6qZPmc1fVp
# Total Value USD: 61429.00354315342
# --------------------------------------------------
# #10
# Wallet: 2vb8xgTxVuizGB4HjDznxsPUjfBqbUQAhCTeJ6sHEtjS
# Timestamp: 2024-12-17T12:46:06.000Z
# Transaction Hash: 34JLx2eFLweFnE9UuhWvQ5dquqfwkWYPZBNuDxJbdyuFAvu9oEGxng91scgRZkTWmpSRU54aMdPA4AyvDkhgekmH
# Total Value USD: 122193.68475215674
# --------------------------------------------------
# #11
# Wallet: EQ5w8WGPZYpQqYweC1vSXAcDzEV3Xzi3PHexMZy3hFV5
# Timestamp: 2024-12-17T12:46:06.000Z
# Transaction Hash: 31HE2pE4hxJoNUpGwDoZjEq7NYFrvzndiBU5hs4ujXRVJUSGeSTrBbX2ZQ5YuXviGpqmXK7A2ueHemaLMpoHp6sf
# Total Value USD: 3662.111433792092
# --------------------------------------------------
# #12
# Wallet: 2XjPxq6bdTRGcQDUtgH1dHZEMPbJXXobnzMKXEqHERnw
# Timestamp: 2024-12-17T12:46:06.000Z
# Transaction Hash: 3hcNo2LW977CqisjuSasKAxGAuqnMs2mpKNs2wiVS93gT3XJZYVHdMVJYMvWkStYrc3GVe9stpkuqcvV9Wp5Wtwq
# Total Value USD: 275283.46839189203
# --------------------------------------------------
# #13
# Wallet: CeoexdLDkYm7YnSSNUBbr9jdW2rwk583UgLzb8ScWAzP
# Timestamp: 2024-12-17T12:46:06.000Z
# Transaction Hash: gPFwHTijYspja7JZTDgF7YxdJxvbhNPW8n3t8ao4ph5CRFR1MtHApYcFBu6jcSTxacMpZHpxKMjh8tzgET7UMMM
# Total Value USD: 6100.130328961104
# --------------------------------------------------
# #14
# Wallet: 63ij5wqq2ZQF86uLoH5aH3fZBNyqK9smemuqn7srpZwM
# Timestamp: 2024-12-17T12:46:06.000Z
# Transaction Hash: A2YjPGUsYSbExLNRRSvuRgh2eEcqrd14tiAJ8ruvT4xC85kmrefAjbxkwWRX694HTyYS2najbLgqToSYdYwQvy6
# Total Value USD: 9.51169056708386
# --------------------------------------------------
# #15
# Wallet: CbXjSiBuNT4iSrXXoowBtxdUc2b3d53y7dRzERDH3vP4
# Timestamp: 2024-12-17T12:46:06.000Z
# Transaction Hash: 5TSRLMhZJTzowYxCbyH85jG6yecX9zZiYGoSPwH7967vfwHXtCmMmCJcg5w2DBD98Y4LKP2h233zoktekzjyg5pu
# Total Value USD: 697.5150850031235
# --------------------------------------------------
# #16
# Wallet: 5NTkFDToxHxbHWMiDxsCUYaZVgXWVancynYqfGUtLV2n
# Timestamp: 2024-12-17T12:46:06.000Z
# Transaction Hash: 26vABFqfM6NJcbc4xD63fMH2dsRsZpjRX55D2biyvx6tmJiogDjoPCMM7NFzgMQ8ez4e8d5GqSgwwn3u6AFFAbeU
# Total Value USD: 222.07196168888476
# --------------------------------------------------
# #17
# Wallet: 8XMK6UKLyQeJ2CE241PUhtQxrHytpj4GpyZQ1b1wvmL6
# Timestamp: 2024-12-17T12:46:06.000Z
# Transaction Hash: 4rdQtzAWEtURBQqU9MfC14Bu1uCqqqdG9GSQGJC4fQ22VMF4LPsAFE9KTWMdR5eCs43HfNEsLoznjrDFojXbcVUa
# Total Value USD: 93.7492780673044
# --------------------------------------------------
# #18
# Wallet: GpEs9fMUHUB5HdsZrpx8SrD5wS3BmJsdirtBzbEfQESo
# Timestamp: 2024-12-17T12:46:06.000Z
# Transaction Hash: 5FpjbyS1vU8rMHmo4dKx7yxWgoRpMi7VVzCh6shPLBCJyW66d6kuDrGby4TeSmgQ2Tyyocyta2VyLzSTv27FUcoH
# Total Value USD: 24.920063337382974
# --------------------------------------------------
#
# 💾 Saved to: C:\Users\daddy brian\Desktop\projects\degenvilla\database\2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv_first_20_buyers.pkl

# %%
import os
import requests
from dotenv import load_dotenv
from joblib import dump

# ========================
# LOAD ENV
# ========================
load_dotenv()
MORALIS_API_KEY = os.getenv("MORALIS_API_KEY")
if not MORALIS_API_KEY:
    raise ValueError("MORALIS_API_KEY not set in .env")

# ========================
# DYNAMIC TOKEN INPUT
# ========================
TOKEN_MINT = input("Enter Solana token mint address: ").strip()
if not TOKEN_MINT:
    raise ValueError("Token mint address cannot be empty")

# ========================
# DATABASE PATH
# ========================
DB_PATH = r"C:\Users\daddy brian\Desktop\projects\degenvilla\database"
if not os.path.exists(DB_PATH):
    os.makedirs(DB_PATH)

SAVE_FILE = os.path.join(DB_PATH, f"{TOKEN_MINT}_earliest_buyer.pkl")

# ========================
# FETCH EARLIEST BUYER
# ========================
url = f"https://solana-gateway.moralis.io/token/mainnet/{TOKEN_MINT}/swaps"

headers = {
    "accept": "application/json",
    "X-API-Key": MORALIS_API_KEY
}

params = {
    "limit": 50,                 # enough to ensure earliest buy
    "order": "ASC",              # earliest first
    "transactionTypes": "buy"    # buyers only
}

response = requests.get(url, headers=headers, params=params)
if response.status_code != 200:
    print("Error:", response.status_code, response.text)
    raise SystemExit

results = response.json().get("result", [])

if not results:
    print(f"⚠️ No buy transactions found for token {TOKEN_MINT}.")
    raise SystemExit

# ========================
# EXTRACT EARLIEST BUYER
# ========================
earliest_tx = results[0]

earliest_buyer = {
    "walletAddress": earliest_tx.get("walletAddress"),
    "blockTimestamp": earliest_tx.get("blockTimestamp"),
    "transactionHash": earliest_tx.get("transactionHash"),
    "totalValueUsd": earliest_tx.get("totalValueUsd")
}

# ========================
# SAVE TO FILE
# ========================
dump(earliest_buyer, SAVE_FILE)

# ========================
# OUTPUT
# ========================
print("✅ Earliest buyer saved successfully\n")
print("Wallet:", earliest_buyer["walletAddress"])
print("Timestamp:", earliest_buyer["blockTimestamp"])
print("Transaction Hash:", earliest_buyer["transactionHash"])
print("Total Value USD:", earliest_buyer["totalValueUsd"])
print("Saved to:", SAVE_FILE)
# Out:
# ✅ Earliest buyer saved successfully
#
# Wallet: 7tRcXDZMjg2CwrgeJ6q2dwU3h3b6tCHcPWSZFKag3kYz
# Timestamp: 2024-12-17T12:46:04.000Z
# Transaction Hash: 2skfjsbTuia8MF75hiwLbLgvnC2CRBc3A72CDLuTGdnMpT89RNRbyjeMagK9UE4JuuyGLSnLPv766UhjTatbaKAF
# Total Value USD: 10357.236120205242
# Saved to: C:\Users\daddy brian\Desktop\projects\degenvilla\database\2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv_earliest_buyer.pkl

# %%
from joblib import load
import pandas as pd

path = r"C:\Users\daddy brian\Desktop\projects\degenvilla\database\earliest_buyer.pkl"

data = load(path)

# Convert to DataFrame (handle both dict and list)
if isinstance(data, list):
    df = pd.DataFrame(data)
else:
    df = pd.DataFrame([data])

print(df)
# Out:
#                                   walletAddress            blockTimestamp  \
# 0  Dd9Hf78VoEWZ9qt9Szw2EsYBfjJkNcE4Za6gRC2LagK7  2024-09-01T06:38:13.000Z
#
#                                      transactionHash  totalValueUsd
# 0  2EBiUgLmxRUZ51GzCWHJL43A92kvdZNB4ffRc25jrmLAa5...         13.219

# %% [markdown]
# daily inflow and outflow

# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
from datetime import datetime

# ==========================
# LOAD ENV
# ==========================
load_dotenv()
BIRDEYE_API_KEY = os.getenv("BIRDEYE_API_KEY")
if not BIRDEYE_API_KEY:
    raise ValueError("BIRDEYE_API_KEY not set in .env")

# ==========================
# DYNAMIC TOKEN INPUT
# ==========================
TOKEN_MINT = input("Enter Solana token mint address: ").strip()
if not TOKEN_MINT:
    raise ValueError("Token mint address cannot be empty")

# ==========================
# API CALL
# ==========================
url = "https://public-api.birdeye.so/defi/v3/token/trade-data/single"

headers = {
    "accept": "application/json",
    "x-chain": "solana",
    "x-api-key": BIRDEYE_API_KEY
}

params = {
    "address": TOKEN_MINT,
    "ui_amount_mode": "scaled"  # human-readable amounts
}

response = requests.get(url, headers=headers, params=params)
if response.status_code != 200:
    print("Error:", response.status_code, response.text)
    raise SystemExit

data = response.json().get("data", {})

# ==========================
# BUILD DAILY FLOW
# ==========================
today = datetime.utcnow().date()

daily_flow = {
    "date": today,
    "token": TOKEN_MINT,
    "inflow": data.get("volume_buy_24h", 0),
    "outflow": data.get("volume_sell_24h", 0),
    "inflow_usd": data.get("volume_buy_24h_usd", 0),
    "outflow_usd": data.get("volume_sell_24h_usd", 0),
}

daily_flow["net_flow"] = daily_flow["inflow"] - daily_flow["outflow"]
daily_flow["net_flow_usd"] = daily_flow["inflow_usd"] - daily_flow["outflow_usd"]

df = pd.DataFrame([daily_flow])

print("\n📊 24h Token Flow Data:")
print(df)
# Out:
# 📊 24h Token Flow Data:
#          date                                        token        inflow  \
# 0  2026-01-20  WENWENvqqNya429ubCdR81ZmD69brwQaaBYY6p3LCpk  5.271119e+09
#
#         outflow    inflow_usd   outflow_usd      net_flow  net_flow_usd
# 0  4.796579e+09  43928.772054  39894.578337  4.745403e+08   4034.193717
# C:\Users\daddy brian\AppData\Local\Temp\ipykernel_13536\3295987527.py:48: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   today = datetime.utcnow().date()

# %%
from joblib import load

path = r"C:\Users\daddy brian\Desktop\projects\degenvilla\database\wenwen_daily_flows.pkl"

# Load the saved DataFrame
df = load(path)

# Confirm type and preview
print(type(df))  # should be <class 'pandas.core.frame.DataFrame'>
print(df.head(20))
# Out:
# <class 'pandas.core.frame.DataFrame'>
#          date  volume_buy_24h_usd  volume_sell_24h_usd  volume_buy_24h  \
# 0  2026-01-20        46427.083618         41982.620203    5.569248e+09
#
#    volume_sell_24h     price  estimated_cost_usd  estimated_profit_usd  \
# 0     5.050546e+09  0.000008        32498.958532          13928.125085
#
#    net_flow_usd
# 0   4444.463415

# %% [markdown]
# total bought, present value

# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
from joblib import dump

# ========================
# LOAD ENV
# ========================
load_dotenv()
MORALIS_API_KEY = os.getenv("MORALIS_API_KEY")
BIRDEYE_API_KEY = os.getenv("BIRDEYE_API_KEY")

if not MORALIS_API_KEY or not BIRDEYE_API_KEY:
    raise ValueError("API keys not found in .env")


# ========================
# DYNAMIC TOKEN INPUT
# ========================
TOKEN_MINT = input("Enter Solana token mint address: ").strip()
if not TOKEN_MINT:
    raise ValueError("Token mint address cannot be empty")

# ========================
# CONFIG (STATIC)
# ========================
CHAIN = "mainnet"
LIMIT = 100
DB_PATH = r"C:\Users\daddy brian\Desktop\projects\degenvilla\database\wallets.pkl"


# ========================
# 1. FETCH TOKEN SWAPS
# ========================
url = f"https://solana-gateway.moralis.io/token/{CHAIN}/{TOKEN_MINT}/swaps"
headers = {"accept": "application/json", "X-API-Key": MORALIS_API_KEY}
params = {"limit": LIMIT, "order": "ASC"}

res = requests.get(url, headers=headers, params=params)
res.raise_for_status()
transfers = res.json().get("result", [])

# ========================
# 2. EXTRACT WENWEN BUY TRANSACTIONS
# ========================
rows = []
for tx in transfers:
    if tx.get("transactionType") == "buy":
        wallet = tx.get("walletAddress")
        bought = tx.get("bought")
        amount = 0
        if isinstance(bought, dict) and bought.get("address") == TOKEN_MINT:
            try:
                amount = float(bought.get("amount", 0))
            except Exception:
                amount = 0
        if wallet and amount > 0:
            rows.append({"wallet": wallet, "wenwen_bought": amount})

df = pd.DataFrame(rows)

if df.empty:
    raise ValueError("⚠️ No WENWEN buy transactions found")

# ========================
# 3. SUM BUYS PER WALLET
# ========================
wallet_buys = df.groupby("wallet", as_index=False)["wenwen_bought"].sum()

# ========================
# 4. GET CURRENT PRICE FROM BIRDEYE
# ========================
price_url = "https://public-api.birdeye.so/defi/price"
price_headers = {"accept": "application/json", "X-API-KEY": BIRDEYE_API_KEY, "x-chain": "solana"}
price_params = {"address": TOKEN_MINT}

price_res = requests.get(price_url, headers=price_headers, params=price_params)
price_res.raise_for_status()
current_price = price_res.json()["data"]["value"]

# ========================
# 5. ESTIMATE PROFIT
# ========================
ESTIMATED_AVG_BUY_PRICE = current_price * 0.7  # conservative assumption

wallet_buys["avg_buy_price"] = ESTIMATED_AVG_BUY_PRICE
wallet_buys["current_price"] = current_price
wallet_buys["cost_basis_usd"] = wallet_buys["wenwen_bought"] * wallet_buys["avg_buy_price"]
wallet_buys["current_value_usd"] = wallet_buys["wenwen_bought"] * wallet_buys["current_price"]
wallet_buys["estimated_profit_usd"] = wallet_buys["current_value_usd"] - wallet_buys["cost_basis_usd"]

# ========================
# 6. SORT AND SAVE
# ========================
wallet_buys = wallet_buys.sort_values("estimated_profit_usd", ascending=False)

print(wallet_buys.head(25))

dump(wallet_buys, DB_PATH)
print(f"\n💾 Data saved to {DB_PATH}")
# Out:
#                                           wallet  wenwen_bought  \
# 5   5PF3KYmUAsXk4zaaH53StcHa3ULEXD1cxQQyM93JLQUy   1.065128e+07
# 9   ARfWSP2bRQh12qCA2XoefaKrpuCU5TRbvjJ9fDXLrqkU   1.037090e+06
# 12  D5AKRGcjAiquuFKcMu5isFTNqHYsAuyYto6ZuYg4eikr   5.843668e+05
# 3   56DFNFWnyRT6oqJq59q3i226Q25YWN7aoUdv6Ujw6Su7   3.566926e+05
# 13  DCAK36VfExkPdAkYUQg6ewgxyinvcEyPLyHjRbmveKFw   3.090905e+05
# 14  Dd9Hf78VoEWZ9qt9Szw2EsYBfjJkNcE4Za6gRC2LagK7   1.545810e+05
# 10  BUAh7Btg1vNiNKKxRQXN8Vq8JVm8CYLJENV8pwWMtrZW   1.215557e+05
# 7   7LFYBv2FQDY6aw5hL5SBCW2PiHG8TmENxBnfUnCksRbs   6.973179e+04
# 2   4Fox2sAeL35PSBM6TpsZQoR6jp9Ljn1pHRHhjXjyKkB2   2.790420e+04
# 19   xGexTsXWrM6nrXErxrwS4u877EUKiHbXMiVe5rhVxbv   1.982537e+04
# 18   sp1fGHhrcqZ7aoRaQkDCvN92KPiYGaghqFoVqbM97wV   1.799102e+04
# 16  FaoqbZtEnpfSpbSm86VLcwSKiqgWAPfnkPeaEWvFJ5ec   1.760999e+04
# 8   8sjorkPQjyQmJjzagbbtJBNR2F59zBF1KJzZ4L8YNM8v   6.201800e+03
# 11  C7buRVxyAiB1aVMVPEJXJgtj3wY5iyaz1SJhBX56joEL   5.328521e+03
# 0   2aSCMZkhFDHDM3bnfViZ3S8BaA4ghYAVRM8havRwv3vD   4.135869e+03
# 6   62tWnYF3z73Zv6T86Na8fqhaw8Xk7jnfdirBsaaYz7KP   3.722505e+03
# 17   excomXdtDV4AniSnnMRgW8NoaUvM8gQCnBzF1ijozjo   1.301231e+03
# 15  Ee7oGQLorSg8tapxb4ym7Y7vAZUuYHMZEgC6boQQJrcP   2.320148e+02
# 1   3FLi39QpEuYZL6YEnefLTpaifd4EFXMtQP7M5Vy91qwF   1.657809e+02
# 4   5FgP8x2LBsisNQDkWUdd63AAFzqTWM6fg1pjsffYBDhc   1.555154e+02
#
#     avg_buy_price  current_price  cost_basis_usd  current_value_usd  \
# 5        0.000006       0.000008       60.991349          87.130498
# 9        0.000006       0.000008        5.938578           8.483683
# 12       0.000006       0.000008        3.346199           4.780285
# 3        0.000006       0.000008        2.042492           2.917845
# 13       0.000006       0.000008        1.769913           2.528447
# 14       0.000006       0.000008        0.885161           1.264516
# 10       0.000006       0.000008        0.696052           0.994359
# 7        0.000006       0.000008        0.399298           0.570426
# 2        0.000006       0.000008        0.159785           0.228264
# 19       0.000006       0.000008        0.113524           0.162177
# 18       0.000006       0.000008        0.103020           0.147172
# 16       0.000006       0.000008        0.100838           0.144055
# 8        0.000006       0.000008        0.035513           0.050732
# 11       0.000006       0.000008        0.030512           0.043589
# 0        0.000006       0.000008        0.023683           0.033833
# 6        0.000006       0.000008        0.021316           0.030451
# 17       0.000006       0.000008        0.007451           0.010644
# 15       0.000006       0.000008        0.001329           0.001898
# 1        0.000006       0.000008        0.000949           0.001356
# 4        0.000006       0.000008        0.000891           0.001272
#
#     estimated_profit_usd
# 5              26.139149
# 9               2.545105
# 12              1.434085
# 3               0.875354
# 13              0.758534
# 14              0.379355
# 10              0.298308
# 7               0.171128
# 2               0.068479
# 19              0.048653
# 18              0.044151
# 16              0.043216
# 8               0.015220
# 11              0.013077
# 0               0.010150
# 6               0.009135
# 17              0.003193
# 15              0.000569
# 1               0.000407
# 4               0.000382
#
# 💾 Data saved to C:\Users\daddy brian\Desktop\projects\degenvilla\database\wallets.pkl

# %% [markdown]
# most profitable wallet

# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
from joblib import dump

# ========================
# LOAD ENV
# ========================
load_dotenv()
MORALIS_API_KEY = os.getenv("MORALIS_API_KEY")
BIRDEYE_API_KEY = os.getenv("BIRDEYE_API_KEY")

if not MORALIS_API_KEY or not BIRDEYE_API_KEY:
    raise ValueError("API keys not found in .env")

# ========================
# DYNAMIC TOKEN INPUT
# ========================
TOKEN_MINT = input("Enter Solana token mint address: ").strip()
if not TOKEN_MINT:
    raise ValueError("Token mint address cannot be empty")

# ========================
# CONFIG (STATIC)
# ========================
CHAIN = "mainnet"
LIMIT = 100
DB_PATH_FULL = r"C:\Users\daddy brian\Desktop\projects\degenvilla\database\wenwen_wallets.pkl"
DB_PATH_TOP20 = r"C:\Users\daddy brian\Desktop\projects\degenvilla\database\wenwen_top20.pkl"

# ========================
# 1. FETCH TOKEN SWAPS
# ========================
url = f"https://solana-gateway.moralis.io/token/{CHAIN}/{TOKEN_MINT}/swaps"
headers = {"accept": "application/json", "X-API-Key": MORALIS_API_KEY}
params = {"limit": LIMIT, "order": "ASC"}

res = requests.get(url, headers=headers, params=params)
res.raise_for_status()
transfers = res.json().get("result", [])

# ========================
# 2. EXTRACT WENWEN BUY TRANSACTIONS
# ========================
rows = []
for tx in transfers:
    if tx.get("transactionType") == "buy":
        wallet = tx.get("walletAddress")
        amount = 0
        try:
            bought = tx.get("bought")
            if isinstance(bought, dict) and bought.get("address") == TOKEN_MINT:
                amount = float(bought.get("amount", 0))
            usd_spent = float(tx.get("totalValueUsd", 0))
        except Exception:
            amount, usd_spent = 0, 0

        if wallet and amount > 0:
            rows.append({
                "wallet": wallet,
                "wenwen_bought": amount,
                "total_bought_usd": usd_spent
            })

df = pd.DataFrame(rows)

if df.empty:
    raise ValueError("⚠️ No WENWEN buy transactions found")

# ========================
# 3. SUM BUYS PER WALLET
# ========================
wallet_buys = df.groupby("wallet", as_index=False).agg({
    "wenwen_bought": "sum",
    "total_bought_usd": "sum"
})

# ========================
# 4. GET CURRENT PRICE FROM BIRDEYE
# ========================
price_url = "https://public-api.birdeye.so/defi/price"
price_headers = {"accept": "application/json", "X-API-KEY": BIRDEYE_API_KEY, "x-chain": "solana"}
price_params = {"address": TOKEN_MINT}

price_res = requests.get(price_url, headers=price_headers, params=price_params)
price_res.raise_for_status()
current_price = price_res.json()["data"]["value"]

# ========================
# 5. CALCULATE CURRENT VALUE & PROFIT
# ========================
wallet_buys["current_value_usd"] = wallet_buys["wenwen_bought"] * current_price
wallet_buys["estimated_profit_usd"] = wallet_buys["current_value_usd"] - wallet_buys["total_bought_usd"]

# ROI = profit / total spent
wallet_buys["profit_percent"] = (wallet_buys["estimated_profit_usd"] / wallet_buys["total_bought_usd"]) * 100

# ========================
# 6. SORT AND SAVE
# ========================
wallet_buys = wallet_buys.sort_values("profit_percent", ascending=False)

# Save full dataset
dump(wallet_buys, DB_PATH_FULL)

# Top 20 wallets by ROI
top20 = wallet_buys.head(20)
dump(top20, DB_PATH_TOP20)

# ========================
# 7. OUTPUT
# ========================
print("🏆 Top 20 Most Profitable WENWEN Wallets (by ROI):\n")
print(top20)
print(f"\n💾 Full wallet data saved to {DB_PATH_FULL}")
print(f"💾 Top 20 wallets saved to {DB_PATH_TOP20}")
# Out:
# 🏆 Top 20 Most Profitable WENWEN Wallets (by ROI):
#
#                                           wallet  wenwen_bought  \
# 18   sp1fGHhrcqZ7aoRaQkDCvN92KPiYGaghqFoVqbM97wV   1.799102e+04
# 4   5FgP8x2LBsisNQDkWUdd63AAFzqTWM6fg1pjsffYBDhc   1.555154e+02
# 3   56DFNFWnyRT6oqJq59q3i226Q25YWN7aoUdv6Ujw6Su7   3.566926e+05
# 10  BUAh7Btg1vNiNKKxRQXN8Vq8JVm8CYLJENV8pwWMtrZW   1.215557e+05
# 17   excomXdtDV4AniSnnMRgW8NoaUvM8gQCnBzF1ijozjo   1.301231e+03
# 8   8sjorkPQjyQmJjzagbbtJBNR2F59zBF1KJzZ4L8YNM8v   6.201800e+03
# 5   5PF3KYmUAsXk4zaaH53StcHa3ULEXD1cxQQyM93JLQUy   1.065128e+07
# 19   xGexTsXWrM6nrXErxrwS4u877EUKiHbXMiVe5rhVxbv   1.982537e+04
# 7   7LFYBv2FQDY6aw5hL5SBCW2PiHG8TmENxBnfUnCksRbs   6.973179e+04
# 16  FaoqbZtEnpfSpbSm86VLcwSKiqgWAPfnkPeaEWvFJ5ec   1.760999e+04
# 2   4Fox2sAeL35PSBM6TpsZQoR6jp9Ljn1pHRHhjXjyKkB2   2.790420e+04
# 11  C7buRVxyAiB1aVMVPEJXJgtj3wY5iyaz1SJhBX56joEL   5.328521e+03
# 14  Dd9Hf78VoEWZ9qt9Szw2EsYBfjJkNcE4Za6gRC2LagK7   1.545810e+05
# 1   3FLi39QpEuYZL6YEnefLTpaifd4EFXMtQP7M5Vy91qwF   1.657809e+02
# 12  D5AKRGcjAiquuFKcMu5isFTNqHYsAuyYto6ZuYg4eikr   5.843668e+05
# 9   ARfWSP2bRQh12qCA2XoefaKrpuCU5TRbvjJ9fDXLrqkU   1.037090e+06
# 15  Ee7oGQLorSg8tapxb4ym7Y7vAZUuYHMZEgC6boQQJrcP   2.320148e+02
# 6   62tWnYF3z73Zv6T86Na8fqhaw8Xk7jnfdirBsaaYz7KP   3.722505e+03
# 0   2aSCMZkhFDHDM3bnfViZ3S8BaA4ghYAVRM8havRwv3vD   4.135869e+03
# 13  DCAK36VfExkPdAkYUQg6ewgxyinvcEyPLyHjRbmveKFw   3.090905e+05
#
#     total_bought_usd  current_value_usd  estimated_profit_usd  profit_percent
# 18          0.000000           0.147098              0.147098             inf
# 4           0.013272           0.001272             -0.012000      -90.419524
# 3          30.451863           2.916380            -27.535483      -90.422984
# 10         10.383208           0.993860             -9.389348      -90.428199
# 17          0.111157           0.010639             -0.100518      -90.428753
# 8           0.529793           0.050707             -0.479086      -90.428913
# 5         909.921123          87.086741           -822.834382      -90.429199
# 19          1.694005           0.162096             -1.531910      -90.431221
# 7           5.958683           0.570139             -5.388544      -90.431793
# 16          1.505462           0.143982             -1.361479      -90.436002
# 2           2.385846           0.228150             -2.157696      -90.437372
# 11          0.455613           0.043567             -0.412046      -90.437745
# 14         13.219000           1.263881            -11.955119      -90.438907
# 1           0.014181           0.001355             -0.012826      -90.441989
# 12         49.997406           4.777884            -45.219522      -90.443736
# 9          88.746259           8.479423            -80.266836      -90.445318
# 15          0.019854           0.001897             -0.017957      -90.445494
# 6           0.318582           0.030436             -0.288146      -90.446465
# 0           0.353970           0.033816             -0.320154      -90.446767
# 13         26.501556           2.527177            -23.974378      -90.464042
#
# 💾 Full wallet data saved to C:\Users\daddy brian\Desktop\projects\degenvilla\database\wenwen_wallets.pkl
# 💾 Top 20 wallets saved to C:\Users\daddy brian\Desktop\projects\degenvilla\database\wenwen_top20.pkl

# %%
import os
import requests
from dotenv import load_dotenv

load_dotenv()

MORALIS_API_KEY = os.getenv("MORALIS_API_KEY")
if not MORALIS_API_KEY:
    raise ValueError("MORALIS_API_KEY not set in .env")


def get_wallet_portfolio(wallet_address: str):
    url = (
        f"https://solana-gateway.moralis.io/account/mainnet/"
        f"{wallet_address}/portfolio"
    )

    params = {
        "nftMetadata": "false",
        "mediaItems": "false",
        "excludeSpam": "true"
    }

    headers = {
        "Accept": "application/json",
        "X-API-Key": MORALIS_API_KEY
    }

    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()
    return response.json()


# ========================
# Example usage
# ========================
wallet = input("Enter Solana wallet address: ").strip()
data = get_wallet_portfolio(wallet)

print(data)
# Out:
# {'nativeBalance': {'lamports': '188386478258', 'solana': '188.386478258'}, 'tokens': [{'associatedTokenAddress': '126CXqq1bc1hdqmKV76D3Yz2ugurKcEHMvpAnbCaZ1mq', 'mint': 'CynjyzQdfwcuLszJtwuXMuqrDqNibgCKGQCmUjdTpump', 'amountRaw': '839116575', 'amount': '839.116575', 'decimals': 6, 'tokenStandard': 2, 'name': 'Thanks 4 Playing', 'symbol': '4', 'score': 24, 'logo': 'https://logo.moralis.io/solana-mainnet_CynjyzQdfwcuLszJtwuXMuqrDqNibgCKGQCmUjdTpump_bfa5b72281a95c186b8e761f8631ed28.webp', 'isVerifiedContract': False, 'possibleSpam': False}, {'associatedTokenAddress': '129n29K3irQUzyz9fYHwHnyi5mci6pypnxzk6Stpe9W1', 'mint': '4xYrnBTdACYetkJEAP4gj4bLFfKw9YYv1nvSWyS1pump', 'amountRaw': '503016229', 'amount': '503.016229', 'decimals': 6, 'tokenStandard': 2, 'name': 'QuantumMeow', 'symbol': 'QMEOW', 'score': 47, 'logo': 'https://logo.moralis.io/solana-mainnet_4xYrnBTdACYetkJEAP4gj4bLFfKw9YYv1nvSWyS1pump_f41e55ebf3fdcf7f77844cafbc9b2c4b.webp', 'isVerifiedContract': False, 'possibleSpam': False}, {'associatedTokenAddress': '12M6FF2Lp37bSSQkvrzMTh1ogoC55dDqJzwTrVFuuyHU', 'mint': 'SonicxvLud67EceaEzCLRnMTBqzYUUYNr93DBkBdDES', 'amountRaw': '3972136895', 'amount': '3.972136895', 'decimals': 9, 'tokenStandard': 2, 'name': 'Sonic SVM', 'symbol': 'SONIC', 'score': 65, 'logo': 'https://logo.moralis.io/solana-mainnet_SonicxvLud67EceaEzCLRnMTBqzYUUYNr93DBkBdDES_fa0dc30a1f4833de.webp', 'isVerifiedContract': True, 'possibleSpam': False}, {'associatedTokenAddress': '12QTXug2Pmui8tuwQ55XfZrDHjBvBNMvKufYFc89sTmV', 'mint': '9bxaVJmUwSc71j8Z2pvUL3UAr1s5fCnwUpvYhqV9jtmw', 'amountRaw': '6036092', 'amount': '6.036092', 'decimals': 6, 'tokenStandard': 2, 'name': 'Mewing Coin', 'symbol': 'MEWING', 'score': 43, 'logo': 'https://logo.moralis.io/solana-mainnet_9bxaVJmUwSc71j8Z2pvUL3UAr1s5fCnwUpvYhqV9jtmw_d95ceab80de362ee.webp', 'isVerifiedContract': True, 'possibleSpam': False}, {'associatedTokenAddress': '12qvJrfSz5TqQXGbNT6659EsG5GMdycQfVFF2ikcDthE', 'mint': '26VG1ZzRC6n2Ch43FUMMUR4c9XKBuKb24EDX5h1Sop7c', 'amountRaw': '3274220000000', 'amount': '3274.22', 'decimals': 9, 'tokenStandard': 2, 'name': 'gooncoin', 'symbol': 'GOONC', 'score': None, 'logo': 'https://logo.moralis.io/solana-mainnet_26VG1ZzRC6n2Ch43FUMMUR4c9XKBuKb24EDX5h1Sop7c_19f72a749316b831ebb63d58fd160f0f.webp', 'isVerifiedContract': False, 'possibleSpam': False}, {'associatedTokenAddress': '13grLwVpavEa8TTA8DseeyRooE4CkZAAHUeHe4aKnBDD', 'mint': '2oJYaVvNKWvhRHDaNwEH225qtG5ZCZiJy6QTLjRtErxW', 'amountRaw': '5299000000', 'amount': '5299', 'decimals': 6, 'tokenStandard': 2, 'name': 'KalmanCoin', 'symbol': 'KFC', 'score': None, 'logo': 'https://logo.moralis.io/solana-mainnet_2oJYaVvNKWvhRHDaNwEH225qtG5ZCZiJy6QTLjRtErxW_c62f9fdaa4e638ae0a843055a93a2948.webp', 'isVerifiedContract': False, 'possibleSpam': False}, {'associatedTokenAddress': '13sGjY3McRb3cz3RmG8Rqam3vod54AWFJLrQRueN6oq9', 'mint': '48KzP8exYyVNKe8ybhN7u6iPscQ3ZNrgeJMQXsmTpump', 'amountRaw': '8303137', 'amount': '8.303137', 'decimals': 6, 'tokenStandard': 2, 'name': '67 COIN', 'symbol': '67', 'score': None, 'logo': 'https://logo.moralis.io/solana-mainnet_48KzP8exYyVNKe8ybhN7u6iPscQ3ZNrgeJMQXsmTpump_1b02830c844f5faf5c70586bfc495b83.webp', 'isVerifiedContract': False, 'possibleSpam': False}, {'associatedTokenAddress': '13Y1jHGUq7rsnKwnYgVjiXsVEyTLMQNGJm4VQJyichEb', 'mint': '4EHN36LGqwmaf1daCMSy5bZVTmSewJs3fAccY2jzpKjU', 'amountRaw': '108952574739', 'amount': '108952.574739', 'decimals': 6, 'tokenStandard': 2, 'name': 'costco', 'symbol': 'COṢTCO', 'score': None, 'logo': 'https://logo.moralis.io/solana-mainnet_4EHN36LGqwmaf1daCMSy5bZVTmSewJs3fAccY2jzpKjU_032b382cf0554e2f1ca072e9910262ac.webp', 'isVerifiedContract': False, 'possibleSpam': False}, {'associatedTokenAddress': '14KETxtXf8my5n2VUkuPVGXj6iRieZPPx914czicvNB1', 'mint': 'HfFQ6R4okiz2yPC7PNXoeGHRyDHS4R92miPjY4uTpump', 'amountRaw': '385116', 'amount': '0.385116', 'decimals': 6, 'tokenStandard': 2, 'name': 'UP', 'symbol': 'UP', 'score': None, 'logo': 'https://logo.moralis.io/solana-mainnet_HfF ...
